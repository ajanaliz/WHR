# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_palette('colorblind')
import warnings
warnings.filterwarnings('ignore')

# %%
happy = pd.read_csv("data/world-happiness-report-2021.csv")
happy.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %% [markdown]
# Checking for NULL values:

# %%
happy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
happiness_report = happy.drop(['Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
       'Explained by: Log GDP per capita', 'Explained by: Social support',
       'Explained by: Healthy life expectancy',
       'Explained by: Freedom to make life choices',
       'Explained by: Generosity', 'Explained by: Perceptions of corruption', 'Ladder score in Dystopia'], axis = 1)
happiness_report.describe()
# Out:
#        Ladder score  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.532839               9.432208        0.814745
# std        1.073924               1.158601        0.114889
# min        2.523000               6.635000        0.463000
# 25%        4.852000               8.541000        0.750000
# 50%        5.534000               9.569000        0.832000
# 75%        6.255000              10.421000        0.905000
# max        7.842000              11.647000        0.983000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               149.000000                    149.000000  149.000000
# mean                 64.992799                      0.791597   -0.015134
# std                   6.762043                      0.113332    0.150657
# min                  48.478000                      0.382000   -0.288000
# ...

# %%
happiness_report.head()
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe         7.842                 10.775
# 1      Denmark     Western Europe         7.620                 10.933
# 2  Switzerland     Western Europe         7.571                 11.117
# 3      Iceland     Western Europe         7.554                 10.878
# 4  Netherlands     Western Europe         7.464                 10.932
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
# 2           0.942                     74.4                         0.919
# 3           0.983                     73.0                         0.955
# 4           0.942                     72.4                         0.913
#
#    Generosity  Perceptions of corruption  Dystopia + residual
# ...

# %% [markdown]
# # Iran From 2006 to 2021
#
# In this section, we are going to see India from 2006 to 2011. We will see very features with the help of a line plot to see how things are changing over to over. So let’s get started!!
#
# ### Steps involved
#
# - Titles are changed for 2021
# - Secondly, certain columns are removed from the data such as Negative effect and Positive Effect
# - The year is added to the 2021 dataset
# - Finally, Both datasets are joined or concatenated

# %%
happiness_report_older = pd.read_csv('data/world-happiness-report.csv')
iran_1 = happiness_report_older[happiness_report_older['Country name'] == 'Iran'].reset_index(drop=True) 
iran_1 = iran_1.drop(['Positive affect','Negative affect'], axis = 1)
iran_1 = iran_1.fillna(0)
happiness_report['year'] = 2021
iran_2 = happiness_report[happiness_report['Country name'] == 'Iran']
iran_2 = iran_2.rename(columns = {'Ladder score':'Life Ladder',
                'Logged GDP per capita':'Log GDP per capita',
                'Healthy life expectancy':'Healthy life expectancy at birth'})
iran_2 = iran_2.drop(['Dystopia + residual', 'Regional indicator'], axis = 1)
iran = pd.concat([iran_1, iran_2])
iran.reset_index(drop=True, inplace=True)
iran.rename(columns = {'year':'Year'}, inplace=True)
iran.head(5)
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0         Iran  2005        5.308               9.393           0.766
# 1         Iran  2007        5.336               9.497           0.718
# 2         Iran  2008        5.129               9.489           0.633
# 3         Iran  2011        4.768               9.547           0.582
# 4         Iran  2012        4.609               9.458           0.600
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             62.00                         0.651       0.000
# 1                             62.76                         0.533       0.056
# 2                             63.14                         0.601       0.052
# 3                             64.14                         0.798       0.200
# 4                             64.38                         0.764       0.000
#
#    Perceptions of corruption
# 0                      0.636
# ...

# %%
plt.figure(figsize=(18, 6))
sns.lineplot(x='Year', y='Life Ladder', data=iran, marker='o', markersize=10);
sns.set_style('whitegrid')
sns.despine(left=True)
plt.title("Iran's ladder score over the years", fontsize=18, fontweight='bold', pad=20)
plt.xlabel('')
plt.show()

# %% [markdown]
# ### Observation
#
# There are some peaks with respect to Iran’s ladder score as found in the years 2008, 2010, 2012, and 2020. There are likewise sure drops as found in the years 2007, 2009, 2011, and a general low in 2019. A continuous reduction can be seen from 2012 to 2019. The general pattern for the ladder score is diminishing.

# %% [markdown]
# ## Iran’s Log GDP per capita Over the Years

# %%
plt.figure(figsize=(18, 6))
sns.lineplot(x='Year', y='Log GDP per capita', data=iran, marker='o', markersize=10);
sns.set_style('whitegrid')
sns.despine(left=True)
plt.title("Iran's Log GDP per capita over the years", fontsize=18, fontweight='bold', pad=20)
plt.xlabel('')
plt.show()

# %% [markdown]
# ### Observation
#
# Iran’s GDP is steady and stable throughout the years due to sanctions, except for 2020 because of the impacts of the COVID-19 pandemic where it has a sharp crash.

# %% [markdown]
# ## Iran’s Social Support Over the years

# %%
plt.figure(figsize=(18, 6))
sns.lineplot(x='Year', y='Social support', data=iran, marker='o', markersize=10);
sns.set_style('whitegrid')
sns.despine(left=True)
plt.title("Iran's Social support over the years", fontsize=18, fontweight='bold', pad=20)
plt.xlabel('')
plt.show()

# %% [markdown]
# ### Observation
#
# A ton of variety in the social support throughout the long term. There are some unmistakable lows in 2011, 2015, and 2016, 2016 being the most minimal, and some particular highs in 2005, 2017, and 2020. Iran’s social support is on a increasing pattern throughout the long term.

# %% [markdown]
# ## Iran’s Life Expectancy At Birth Over the years

# %%
plt.figure(figsize=(18, 6))
sns.lineplot(x='Year', y='Healthy life expectancy at birth', data=iran, marker='o', markersize=10);
sns.set_style('whitegrid')
sns.despine(left=True)
plt.title("Iran's life expectancy at birth over the years", fontsize=18, fontweight='bold', pad=20)
plt.xlabel('')
plt.show()

# %% [markdown]
# ### Observation
#
# An increasing pattern throughout the long term, with a light drop after 2020 here – however, it’s normal. Coronavirus had struck in 2020, and it would not be astounding that the future has marginally dropped.

# %% [markdown]
# ## Iran’s Freedom To Make Life Choices Over the years

# %%
plt.figure(figsize=(18, 6))
sns.lineplot(x='Year', y='Freedom to make life choices', data=iran, marker='o', markersize=10);
sns.set_style('whitegrid')
sns.despine(left=True)
plt.title("Iran's Freedom to make life choices over the years", fontsize=18, fontweight='bold', pad=20)
plt.xlabel('')
plt.show()

# %% [markdown]
# ### Observation
#
# There’s a slight increasing pattern from 2007 throughout 2011, yet there are distinct drops after as found in the years 2012, 2013, 2017, and 2018.

# %% [markdown]
# ## Iran’s Generosity Over the years

# %%
plt.figure(figsize=(18, 6)) 
sns.lineplot(x='Year', y='Generosity', data=iran, marker='o', markersize=10); sns.set_style('whitegrid') 
sns.despine(left=True) 
plt.title("Iran's Generosity over the years", fontsize=18, fontweight='bold', pad=20) 
plt.xlabel('') 
plt.show()

# %% [markdown]
# ### Observation
#
# Generosity among Iranians has expanded over the long run, with spikes in 2011, 2013, 2014, 2017, and 2021.

# %% [markdown]
# ## Iran’s Perceptions Of Corruption Over the years

# %%
plt.figure(figsize=(18, 6))
sns.lineplot(x='Year', y='Perceptions of corruption', data=iran, marker='o', markersize=10);
sns.set_style('whitegrid')
sns.despine(left=True)
plt.title("Iran's Perceptions of corruption over the years", fontsize=18, fontweight='bold', pad=20)
plt.xlabel('')
plt.show()

# %% [markdown]
# ### Observation
#
# There were tops in 2007-2008, and the perception of corruption has diminished throughout the long term and is steadily rising back up.

# %% [markdown]
# ## Iran and its neighbours
#
#
# In this section, we are going to explore data with respect to our neighbouring countries like Iraq, Afganistan, Armenia, etc.
# How Happy is In Iran Among Its Neighbors?

# %%
top = happiness_report[happiness_report['Country name'] == 'Finland']
south_asia = happiness_report[happiness_report['Regional indicator'] == 'Middle East and North Africa']
top_bottom_neighbors = pd.concat([top, south_asia], axis=0)
top_bottom_neighbors['Rank'] = top_bottom_neighbors.index + 1
top_bottom_neighbors.reset_index(drop=True, inplace=True)
top_bottom_neighbors.drop(['Regional indicator', 'Dystopia + residual', 'year'], axis=1, inplace=True)
df_glob = happiness_report.sort_values('Ladder score', ascending=False)[['Country name', 'Ladder score', 'Regional indicator']].reset_index(drop=True)
top = df_glob[df_glob['Ladder score'] == df_glob['Ladder score'].max()]
neighbors = df_glob[df_glob['Regional indicator'] == 'Middle East and North Africa']
top_bottom_neighbors = pd.concat([top, neighbors], axis=0)
top_bottom_neighbors['Rank'] = list(top_bottom_neighbors.index + 1)
top_bottom_neighbors.reset_index(drop=True, inplace=True)
top_bottom_neighbors.drop('Regional indicator', axis=1, inplace=True)
mean_score = happiness_report['Ladder score'].mean()
rank = list(top_bottom_neighbors['Rank'])
fig, ax = plt.subplots(figsize=(26, 6))
bar = sns.barplot(x='Country name', y='Ladder score', data=top_bottom_neighbors, palette='summer_r')
sns.set_style('whitegrid')
sns.despine(left=True)
for i in range(1, len(top_bottom_neighbors)):
    bar.text(x=i, y=(top_bottom_neighbors['Ladder score'][i])/2, s=str(rank[i])+'th',
                fontdict=dict(color='white', fontsize=12, fontweight='bold', horizontalalignment='center'))
    bar.text(x=0, y=(top_bottom_neighbors['Ladder score'][0])/2, s=str(rank[0])+'st', fontdict=dict(color='white', fontsize=12, fontweight='bold', horizontalalignment='center'))
    bar.axhline(mean_score, color='grey', linestyle='--')
    bar.text(x=len(top_bottom_neighbors)-0.4, y = mean_score, s = 'GlobalnAverage: {:.2f}'.format(mean_score),
            fontdict = dict(color='white', backgroundcolor='grey', fontsize=10, fontweight='bold'))
plt.title('How Happy is Iran Among its Neighbors?', fontsize=18, fontweight='bold', pad=20)
plt.xlabel('')
plt.show()

# %% [markdown]
# ### Observation
#
# Among Middle East and North African nations, Iran positions 12th in the happiness index. In a world setting, India positions 118th, a whole ladder score less than average.

# %% [markdown]
# ## Where does Iran’s Log GDP Rank?

# %%
df_glob = happiness_report.sort_values('Logged GDP per capita', ascending=False)[['Country name', 'Logged GDP per capita', 'Regional indicator']].reset_index(drop=True)
top = df_glob[df_glob['Logged GDP per capita'] == df_glob['Logged GDP per capita'].max()]
neighbors = df_glob[df_glob['Regional indicator'] == 'Middle East and North Africa']
top_bottom_neighbors = pd.concat([top, neighbors], axis=0)
top_bottom_neighbors['Rank'] = list(top_bottom_neighbors.index + 1)
top_bottom_neighbors.reset_index(drop=True, inplace=True)
top_bottom_neighbors.drop('Regional indicator', axis=1, inplace=True)
mean_score = happiness_report['Logged GDP per capita'].mean()
rank = list(top_bottom_neighbors['Rank'])
plt.figure(figsize=(26, 12))
bar = sns.barplot(x='Country name', y='Logged GDP per capita', data=top_bottom_neighbors, palette='summer_r');
sns.set_style('whitegrid')
sns.despine(left=True)
for i in range(1, len(top_bottom_neighbors)):
    bar.text(x=i, y=(top_bottom_neighbors['Logged GDP per capita'][i])/2, s=str(rank[i])+'th',
                fontdict=dict(color='white', fontsize=12, fontweight='bold', horizontalalignment='center'))
    bar.text(x=0, y=(top_bottom_neighbors['Logged GDP per capita'][0])/2, s=str(rank[0])+'st', fontdict=dict(color='white', fontsize=12, fontweight='bold', horizontalalignment='center'))
    bar.axhline(mean_score, color='grey', linestyle='--')
    bar.text(x=len(top_bottom_neighbors)-0.4, y = mean_score, s = 'GlobalnAverage: {:.2f}'.format(mean_score),
            fontdict = dict(color='white', backgroundcolor='grey', fontsize=10, fontweight='bold'))
plt.title("Where does Iran's Log GDP Ranks?", fontsize=18, fontweight='bold', pad=20)
plt.xlabel('')
plt.show()

# %% [markdown]
# ### Observation
#
# Among Middle East and North African nations, Iran positions 9th in Log GDP per Capita scores. In a world setting, India positions 73rd.

# %% [markdown]
# ## Where Does Iran’s Healthy Life Expectancy Ranks?

# %%
df_glob = happiness_report.sort_values('Healthy life expectancy', ascending=False)[['Country name', 'Healthy life expectancy', 'Regional indicator']].reset_index(drop=True)
top = df_glob[df_glob['Healthy life expectancy'] == df_glob['Healthy life expectancy'].max()]
neighbors = df_glob[df_glob['Regional indicator'] == 'Middle East and North Africa']
top_bottom_neighbors = pd.concat([top, neighbors], axis=0)
top_bottom_neighbors['Rank'] = list(top_bottom_neighbors.index + 1)
top_bottom_neighbors.reset_index(drop=True, inplace=True)
top_bottom_neighbors.drop('Regional indicator', axis=1, inplace=True)
mean_score = happiness_report['Healthy life expectancy'].mean()
rank = list(top_bottom_neighbors['Rank'])
plt.figure(figsize=(26, 12))
bar = sns.barplot(x='Country name', y='Healthy life expectancy', data=top_bottom_neighbors, palette='summer_r');
sns.set_style('whitegrid')
sns.despine(left=True)
for i in range(1, len(top_bottom_neighbors)):
    bar.text(x=i, y=(top_bottom_neighbors['Healthy life expectancy'][i])/2, s=str(rank[i])+'th',
                fontdict=dict(color='white', fontsize=12, fontweight='bold', horizontalalignment='center'))
    bar.text(x=0, y=(top_bottom_neighbors['Healthy life expectancy'][0])/2, s=str(rank[0])+'st', fontdict=dict(color='white', fontsize=12, fontweight='bold', horizontalalignment='center'))
    bar.axhline(mean_score, color='grey', linestyle='--')
    bar.text(x=len(top_bottom_neighbors)-0.4, y = mean_score, s = 'GlobalnAverage: {:.2f}'.format(mean_score),
            fontdict = dict(color='white', backgroundcolor='grey', fontsize=10, fontweight='bold'))
plt.title("Where does Iran's Healthy life expectancy Ranks?", fontsize=18, fontweight='bold', pad=20)
plt.xlabel('')
plt.show()

# %% [markdown]
# ### Observation
#
# Among Middle East and North African nations, Iran positions tenth in Healthy life expectancy scores. In a world setting, India positions 78th.

# %% [markdown]
# ## Where Does Iran’s Perceptions of corruption Ranks?

# %%
df_glob = happiness_report.sort_values('Perceptions of corruption', ascending=False)[['Country name', 'Perceptions of corruption', 'Regional indicator']].reset_index(drop=True)
top = df_glob[df_glob['Perceptions of corruption'] == df_glob['Perceptions of corruption'].max()]
neighbors = df_glob[df_glob['Regional indicator'] == 'Middle East and North Africa']
top_bottom_neighbors = pd.concat([top, neighbors], axis=0)
top_bottom_neighbors['Rank'] = list(top_bottom_neighbors.index + 1)
top_bottom_neighbors.reset_index(drop=True, inplace=True)
top_bottom_neighbors.drop('Regional indicator', axis=1, inplace=True)
mean_score = happiness_report['Perceptions of corruption'].mean()
rank = list(top_bottom_neighbors['Rank'])
plt.figure(figsize=(26, 12))
bar = sns.barplot(x='Country name', y='Perceptions of corruption', data=top_bottom_neighbors, palette='summer_r');
sns.set_style('whitegrid')
sns.despine(left=True)
for i in range(1, len(top_bottom_neighbors)):
    bar.text(x=i, y=(top_bottom_neighbors['Perceptions of corruption'][i])/2, s=str(rank[i])+'th',
                fontdict=dict(color='white', fontsize=12, fontweight='bold', horizontalalignment='center'))
    bar.text(x=0, y=(top_bottom_neighbors['Perceptions of corruption'][0])/2, s=str(rank[0])+'st', fontdict=dict(color='white', fontsize=12, fontweight='bold', horizontalalignment='center'))
    bar.axhline(mean_score, color='grey', linestyle='--')
    bar.text(x=len(top_bottom_neighbors)-0.4, y = mean_score, s = 'GlobalnAverage: {:.2f}'.format(mean_score),
            fontdict = dict(color='white', backgroundcolor='grey', fontsize=10, fontweight='bold'))
plt.title("Where does Iran's Perceptions of corruption Ranks?", fontsize=18, fontweight='bold', pad=20)
plt.xlabel('')
plt.show()

# %% [markdown]
# ### Observation
#
# Among Middle East and North African nations, Iran positions fifth from last in Perceptions of corruption scores. In a world setting, Iran positions 102nd

# %% [markdown]
# ## Conclusion
#
# - There are some peaks with respect to Iran’s ladder score as found in the years 2008, 2010, 2012, and 2020. There are likewise sure drops as found in the years 2007, 2009, 2011, and a general low in 2019. A continuous reduction can be seen from 2012 to 2019. The general pattern for the ladder score is diminishing.
# - Iran’s GDP is steady and stable throughout the years due to sanctions, except for 2020 because of the impacts of the COVID-19 pandemic where it has a sharp crash.
# - A ton of variety in the social support throughout the long term. There are some unmistakable lows in 2011, 2015, and 2016, 2016 being the most minimal, and some particular highs in 2005, 2017, and 2020. Iran’s social support is on a increasing pattern throughout the long term.
# - An increasing pattern in Iran's expected life expectancy throughout the long term, with a light drop after 2020 here – however, it’s normal. Coronavirus had struck in 2020, and it would not be astounding that the future has marginally dropped.
# - There’s a slight increasing pattern for Iran's Freedom to make life choices from 2007 throughout 2011, yet there are distinct drops after as found in the years 2012, 2013, 2017, and 2018.
# - Generosity among Iranians has expanded over the long run, with spikes in 2011, 2013, 2014, 2017, and 2021.
# - There were tops in Iran's Perceptions of corruption in 2007-2008, and the perception of corruption has diminished throughout the long term and is steadily rising back up.
# - Among Middle East and North African nations, Iran positions 12th in the happiness index. In a world setting, India positions 118th, a whole ladder score less than average.
# - Among Middle East and North African nations, Iran positions 9th in Log GDP per Capita scores. In a world setting, India positions 73rd.
# - Among Middle East and North African nations, Iran positions tenth in Healthy life expectancy scores. In a world setting, India positions 78th.
# - Among Middle East and North African nations, Iran positions fifth from last in Perceptions of corruption scores. In a world setting, Iran positions 102nd
